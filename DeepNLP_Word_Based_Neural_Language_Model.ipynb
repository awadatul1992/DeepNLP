# %% [markdown]
# <a href="https://colab.research.google.com/github/awadatul1992/DeepNLP/blob/main/DeepNLP_Word_Based_Neural_Language_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# source text
data = """ Jack and Jill went up the hill\n
To fetch a pail of water\n
Jack fell down and broke his crown\n
And Jill came tumbling after\n """

# %% [markdown]
# #One word in one word out

# %%
# integer encode text
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded = tokenizer.texts_to_sequences([data])[0]

# %%
# determine the vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 22

# %%
# create word -> word sequences
sequences = list()
for i in range(1, len(encoded)):
  sequence = encoded[i-1:i+1]
  sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 1

# %%
sequences
# Out:
# [array([2, 1])]

# %%
# split into X and y elements
import numpy as np
sequences = np.array(sequences)
X, y = sequences[:,0],sequences[:,1]

# %%
# one hot encode outputs
from keras.utils import to_categorical
y = to_categorical(y, num_classes=vocab_size)

# %%
# define the model
from keras import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.utils import plot_model
def define_model(vocab_size):
  model = Sequential()
  model.add(Embedding(vocab_size, 10, input_length=1))
  model.add(LSTM(50))
  model.add(Dense(vocab_size, activation='softmax'))
  # compile network
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  # summarize defined model
  model.summary()
  plot_model(model, to_file='model.png', show_shapes=True)
  return model

# %%
model = define_model(vocab_size)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 1, 10)             220
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_3 (Dense)              (None, 22)                1122
# =================================================================
# Total params: 13,542
# Trainable params: 13,542
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs=40, verbose=2)
# Out:
# Epoch 1/40
# 1/1 - 0s - loss: 3.0899 - accuracy: 0.0000e+00
# Epoch 2/40
# 1/1 - 0s - loss: 3.0855 - accuracy: 1.0000
# Epoch 3/40
# 1/1 - 0s - loss: 3.0810 - accuracy: 1.0000
# Epoch 4/40
# 1/1 - 0s - loss: 3.0765 - accuracy: 1.0000
# Epoch 5/40
# 1/1 - 0s - loss: 3.0719 - accuracy: 1.0000
# Epoch 6/40
# 1/1 - 0s - loss: 3.0672 - accuracy: 1.0000
# Epoch 7/40
# 1/1 - 0s - loss: 3.0625 - accuracy: 1.0000
# Epoch 8/40
# 1/1 - 0s - loss: 3.0578 - accuracy: 1.0000
# Epoch 9/40
# 1/1 - 0s - loss: 3.0529 - accuracy: 1.0000
# Epoch 10/40
# 1/1 - 0s - loss: 3.0480 - accuracy: 1.0000
# Epoch 11/40
# 1/1 - 0s - loss: 3.0429 - accuracy: 1.0000
# Epoch 12/40
# 1/1 - 0s - loss: 3.0378 - accuracy: 1.0000
# Epoch 13/40
# 1/1 - 0s - loss: 3.0326 - accuracy: 1.0000
# Epoch 14/40
# 1/1 - 0s - loss: 3.0272 - accuracy: 1.0000
# Epoch 15/40
# 1/1 - 0s - loss: 3.0217 - accuracy: 1.0000
# Epoch 16/40
# 1/1 - 0s - loss: 3.0161 - accuracy: 1.0000
# Epoch 17/40
# 1/1 - 0s - loss: 3.0103 - accuracy: 1.0000
# Epoch 18/40
# 1/1 - 0s - loss: 3.0044 - accuracy: 1.0000
# Epoch 19/40
# 1/1 - 0s - loss: 2.9983 - accuracy: 1.0000
# Epoch 20/40
# 1/1 - 0s - loss: 2.9921 - accuracy: 1.0000
# Epoch 21/40
# 1/1 - 0s - loss: 2.9856 - accuracy: 1.0000
# Epoch 22/40
# 1/1 - 0s - loss: 2.9790 - accuracy: 1.0000
# Epoch 23/40
# 1/1 - 0s - loss: 2.9722 - accuracy: 1.0000
# Epoch 24/40
# 1/1 - 0s - loss: 2.9652 - accuracy: 1.0000
# Epoch 25/40
# 1/1 - 0s - loss: 2.9579 - accuracy: 1.0000
# Epoch 26/40
# 1/1 - 0s - loss: 2.9504 - accuracy: 1.0000
# Epoch 27/40
# 1/1 - 0s - loss: 2.9427 - accuracy: 1.0000
# Epoch 28/40
# 1/1 - 0s - loss: 2.9347 - accuracy: 1.0000
# Epoch 29/40
# 1/1 - 0s - loss: 2.9265 - accuracy: 1.0000
# Epoch 30/40
# 1/1 - 0s - loss: 2.9180 - accuracy: 1.0000
# Epoch 31/40
# 1/1 - 0s - loss: 2.9092 - accuracy: 1.0000
# Epoch 32/40
# 1/1 - 0s - loss: 2.9002 - accuracy: 1.0000
# Epoch 33/40
# 1/1 - 0s - loss: 2.8908 - accuracy: 1.0000
# Epoch 34/40
# 1/1 - 0s - loss: 2.8811 - accuracy: 1.0000
# Epoch 35/40
# 1/1 - 0s - loss: 2.8711 - accuracy: 1.0000
# Epoch 36/40
# 1/1 - 0s - loss: 2.8607 - accuracy: 1.0000
# Epoch 37/40
# 1/1 - 0s - loss: 2.8500 - accuracy: 1.0000
# Epoch 38/40
# 1/1 - 0s - loss: 2.8389 - accuracy: 1.0000
# Epoch 39/40
# 1/1 - 0s - loss: 2.8275 - accuracy: 1.0000
# Epoch 40/40
# 1/1 - 0s - loss: 2.8157 - accuracy: 1.0000

# %%
# evaluate
in_text = 'Jack'
print(in_text)
encoded = tokenizer.texts_to_sequences([in_text])[0]
encoded = np.array(encoded)
yhat = model.predict_classes(encoded, verbose=0)
for word, index in tokenizer.word_index.items():
  if index == yhat:
    print(word)
# Out:
# Jack
# and

# %%
# generate a sequence from the model
def generate_seq(model, tokenizer, seed_text, n_words):
  in_text, result = seed_text, seed_text
  # generate a fixed number of words
  for _ in range(n_words):
    # encode the text as integer
    encoded = tokenizer.texts_to_sequences([in_text])[0]
    encoded = np.array(encoded)
    # predict a word in the vocabulary
    yhat = model.predict_classes(encoded, verbose=0)
    # map predicted word index to word
    out_word = ''
    for word, index in tokenizer.word_index.items():
      if index == yhat:
        out_word = word
        break
  # append to input
    in_text, result = out_word, result + ' ' + out_word
  return result

# %%
generate_seq(model, tokenizer, "Jack", 20)
# Out:
# 'Jack and jill came tumbling after to fetch a pail of water jack and jill came tumbling after to fetch a'

# %% [markdown]
# # Multiple words in one word out

# %%
# source text
data = """ Jack and Jill went up the hill\n
To fetch a pail of water\n
Jack fell down and broke his crown\n
And Jill came tumbling after\n """

# %%
sequences = list()
for line in data.split('\n'):
  encoded = tokenizer.texts_to_sequences([line])[0]
  for i in range(1, len(encoded)):
    sequence = encoded[:i+1]
    sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 21

# %%
sequences
# Out:
# [[2, 1],
#  [2, 1, 3],
#  [2, 1, 3, 4],
#  [2, 1, 3, 4, 5],
#  [2, 1, 3, 4, 5, 6],
#  [2, 1, 3, 4, 5, 6, 7],
#  [8, 9],
#  [8, 9, 10],
#  [8, 9, 10, 11],
#  [8, 9, 10, 11, 12],
#  [8, 9, 10, 11, 12, 13],
#  [2, 14],
#  [2, 14, 15],
#  [2, 14, 15, 1],
#  [2, 14, 15, 1, 16],
#  [2, 14, 15, 1, 16, 17],
#  [2, 14, 15, 1, 16, 17, 18],
#  [1, 3],
#  [1, 3, 19],
#  [1, 3, 19, 20],
#  [1, 3, 19, 20, 21]]

# %%
# pad input sequences
from keras.preprocessing.sequence import pad_sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Max Sequence Length: 7

# %%
# split into input and output elements
sequences = np.array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)

# %%
# define the model
def define_model_line_by_line(vocab_size, max_length):
  model = Sequential()
  model.add(Embedding(vocab_size, 10, input_length=max_length-1))
  model.add(LSTM(50))
  model.add(Dense(vocab_size, activation='softmax'))
  # compile network
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  # summarize defined model
  model.summary()
  plot_model(model, to_file='model.png', show_shapes=True)
  return model

# %%
model_line_by_line = define_model_line_by_line(vocab_size, max_length)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 6, 10)             220
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_1 (Dense)              (None, 22)                1122
# =================================================================
# Total params: 13,542
# Trainable params: 13,542
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_line_by_line.fit(X, y, epochs = 500, verbose = 2)
# Out:
# Epoch 1/500
# 1/1 - 0s - loss: 0.7710 - accuracy: 0.8095
# Epoch 2/500
# 1/1 - 0s - loss: 0.7634 - accuracy: 0.8095
# Epoch 3/500
# 1/1 - 0s - loss: 0.7562 - accuracy: 0.8095
# Epoch 4/500
# 1/1 - 0s - loss: 0.7493 - accuracy: 0.8095
# Epoch 5/500
# 1/1 - 0s - loss: 0.7426 - accuracy: 0.8095
# Epoch 6/500
# 1/1 - 0s - loss: 0.7358 - accuracy: 0.8095
# Epoch 7/500
# 1/1 - 0s - loss: 0.7289 - accuracy: 0.8095
# Epoch 8/500
# 1/1 - 0s - loss: 0.7221 - accuracy: 0.8095
# Epoch 9/500
# 1/1 - 0s - loss: 0.7154 - accuracy: 0.8095
# Epoch 10/500
# 1/1 - 0s - loss: 0.7091 - accuracy: 0.8095
# Epoch 11/500
# 1/1 - 0s - loss: 0.7030 - accuracy: 0.8571
# Epoch 12/500
# 1/1 - 0s - loss: 0.6971 - accuracy: 0.8095
# Epoch 13/500
# 1/1 - 0s - loss: 0.6913 - accuracy: 0.8571
# Epoch 14/500
# 1/1 - 0s - loss: 0.6856 - accuracy: 0.8095
# Epoch 15/500
# 1/1 - 0s - loss: 0.6797 - accuracy: 0.8571
# Epoch 16/500
# 1/1 - 0s - loss: 0.6739 - accuracy: 0.8095
# Epoch 17/500
# 1/1 - 0s - loss: 0.6680 - accuracy: 0.8571
# Epoch 18/500
# 1/1 - 0s - loss: 0.6624 - accuracy: 0.8571
# Epoch 19/500
# 1/1 - 0s - loss: 0.6570 - accuracy: 0.8571
# Epoch 20/500
# 1/1 - 0s - loss: 0.6518 - accuracy: 0.8571
# Epoch 21/500
# 1/1 - 0s - loss: 0.6468 - accuracy: 0.8571
# Epoch 22/500
# 1/1 - 0s - loss: 0.6419 - accuracy: 0.8571
# Epoch 23/500
# 1/1 - 0s - loss: 0.6371 - accuracy: 0.8571
# Epoch 24/500
# 1/1 - 0s - loss: 0.6323 - accuracy: 0.8571
# Epoch 25/500
# 1/1 - 0s - loss: 0.6275 - accuracy: 0.8571
# Epoch 26/500
# 1/1 - 0s - loss: 0.6225 - accuracy: 0.8571
# Epoch 27/500
# 1/1 - 0s - loss: 0.6175 - accuracy: 0.8571
# Epoch 28/500
# 1/1 - 0s - loss: 0.6126 - accuracy: 0.8571
# Epoch 29/500
# 1/1 - 0s - loss: 0.6080 - accuracy: 0.8571
# Epoch 30/500
# 1/1 - 0s - loss: 0.6036 - accuracy: 0.8571
# Epoch 31/500
# 1/1 - 0s - loss: 0.5995 - accuracy: 0.8571
# Epoch 32/500
# 1/1 - 0s - loss: 0.5953 - accuracy: 0.8571
# Epoch 33/500
# 1/1 - 0s - loss: 0.5911 - accuracy: 0.8571
# Epoch 34/500
# 1/1 - 0s - loss: 0.5868 - accuracy: 0.8571
# Epoch 35/500
# 1/1 - 0s - loss: 0.5823 - accuracy: 0.8571
# Epoch 36/500
# 1/1 - 0s - loss: 0.5780 - accuracy: 0.8571
# Epoch 37/500
# 1/1 - 0s - loss: 0.5739 - accuracy: 0.8571
# Epoch 38/500
# 1/1 - 0s - loss: 0.5699 - accuracy: 0.8571
# Epoch 39/500
# 1/1 - 0s - loss: 0.5661 - accuracy: 0.8571
# Epoch 40/500
# 1/1 - 0s - loss: 0.5624 - accuracy: 0.8571
# Epoch 41/500
# 1/1 - 0s - loss: 0.5587 - accuracy: 0.8571
# Epoch 42/500
# 1/1 - 0s - loss: 0.5549 - accuracy: 0.8571
# Epoch 43/500
# 1/1 - 0s - loss: 0.5512 - accuracy: 0.8571
# Epoch 44/500
# 1/1 - 0s - loss: 0.5473 - accuracy: 0.8571
# Epoch 45/500
# 1/1 - 0s - loss: 0.5435 - accuracy: 0.8571
# Epoch 46/500
# 1/1 - 0s - loss: 0.5398 - accuracy: 0.8571
# Epoch 47/500
# 1/1 - 0s - loss: 0.5361 - accuracy: 0.8571
# Epoch 48/500
# 1/1 - 0s - loss: 0.5326 - accuracy: 0.8571
# Epoch 49/500
# 1/1 - 0s - loss: 0.5291 - accuracy: 0.8571
# Epoch 50/500
# 1/1 - 0s - loss: 0.5258 - accuracy: 0.8571
# Epoch 51/500
# 1/1 - 0s - loss: 0.5225 - accuracy: 0.8571
# Epoch 52/500
# 1/1 - 0s - loss: 0.5192 - accuracy: 0.8571
# Epoch 53/500
# 1/1 - 0s - loss: 0.5160 - accuracy: 0.8571
# Epoch 54/500
# 1/1 - 0s - loss: 0.5129 - accuracy: 0.8571
# Epoch 55/500
# 1/1 - 0s - loss: 0.5097 - accuracy: 0.8571
# Epoch 56/500
# 1/1 - 0s - loss: 0.5065 - accuracy: 0.8571
# Epoch 57/500
# 1/1 - 0s - loss: 0.5031 - accuracy: 0.8571
# Epoch 58/500
# 1/1 - 0s - loss: 0.4997 - accuracy: 0.8571
# Epoch 59/500
# 1/1 - 0s - loss: 0.4963 - accuracy: 0.8571
# Epoch 60/500
# 1/1 - 0s - loss: 0.4931 - accuracy: 0.8571
# Epoch 61/500
# 1/1 - 0s - loss: 0.4901 - accuracy: 0.8571
# Epoch 62/500
# 1/1 - 0s - loss: 0.4871 - accuracy: 0.8571
# Epoch 63/500
# 1/1 - 0s - loss: 0.4843 - accuracy: 0.8571
# Epoch 64/500
# 1/1 - 0s - loss: 0.4814 - accuracy: 0.8571
# Epoch 65/500
# 1/1 - 0s - loss: 0.4785 - accuracy: 0.8571
# Epoch 66/500
# 1/1 - 0s - loss: 0.4755 - accuracy: 0.8571
# Epoch 67/500
# 1/1 - 0s - loss: 0.4725 - accuracy: 0.8571
# Epoch 68/500
# 1/1 - 0s - loss: 0.4694 - accuracy: 0.8571
# Epoch 69/500
# 1/1 - 0s - loss: 0.4665 - accuracy: 0.8571
# Epoch 70/500
# 1/1 - 0s - loss: 0.4636 - accuracy: 0.9048
# Epoch 71/500
# 1/1 - 0s - loss: 0.4608 - accuracy: 0.9048
# Epoch 72/500
# 1/1 - 0s - loss: 0.4581 - accuracy: 0.9048
# Epoch 73/500
# 1/1 - 0s - loss: 0.4554 - accuracy: 0.9048
# Epoch 74/500
# 1/1 - 0s - loss: 0.4528 - accuracy: 0.9048
# Epoch 75/500
# 1/1 - 0s - loss: 0.4501 - accuracy: 0.9048
# Epoch 76/500
# 1/1 - 0s - loss: 0.4475 - accuracy: 0.9048
# Epoch 77/500
# 1/1 - 0s - loss: 0.4448 - accuracy: 0.9048
# Epoch 78/500
# 1/1 - 0s - loss: 0.4422 - accuracy: 0.9048
# Epoch 79/500
# 1/1 - 0s - loss: 0.4395 - accuracy: 0.9048
# Epoch 80/500
# 1/1 - 0s - loss: 0.4369 - accuracy: 0.9048
# Epoch 81/500
# 1/1 - 0s - loss: 0.4342 - accuracy: 0.9048
# Epoch 82/500
# 1/1 - 0s - loss: 0.4316 - accuracy: 0.9048
# Epoch 83/500
# 1/1 - 0s - loss: 0.4290 - accuracy: 0.9048
# Epoch 84/500
# 1/1 - 0s - loss: 0.4265 - accuracy: 0.9048
# Epoch 85/500
# 1/1 - 0s - loss: 0.4240 - accuracy: 0.9048
# Epoch 86/500
# 1/1 - 0s - loss: 0.4216 - accuracy: 0.9048
# Epoch 87/500
# 1/1 - 0s - loss: 0.4192 - accuracy: 0.9048
# Epoch 88/500
# 1/1 - 0s - loss: 0.4168 - accuracy: 0.9048
# Epoch 89/500
# 1/1 - 0s - loss: 0.4145 - accuracy: 0.9048
# Epoch 90/500
# 1/1 - 0s - loss: 0.4122 - accuracy: 0.9048
# Epoch 91/500
# 1/1 - 0s - loss: 0.4100 - accuracy: 0.9048
# Epoch 92/500
# 1/1 - 0s - loss: 0.4078 - accuracy: 0.9048
# Epoch 93/500
# 1/1 - 0s - loss: 0.4057 - accuracy: 0.9524
# Epoch 94/500
# 1/1 - 0s - loss: 0.4035 - accuracy: 0.9048
# Epoch 95/500
# 1/1 - 0s - loss: 0.4014 - accuracy: 0.9524
# Epoch 96/500
# 1/1 - 0s - loss: 0.3989 - accuracy: 0.9048
# Epoch 97/500
# 1/1 - 0s - loss: 0.3965 - accuracy: 0.9524
# Epoch 98/500
# 1/1 - 0s - loss: 0.3939 - accuracy: 0.9048
# Epoch 99/500
# 1/1 - 0s - loss: 0.3914 - accuracy: 0.9524
# Epoch 100/500
# 1/1 - 0s - loss: 0.3892 - accuracy: 0.9524
# Epoch 101/500
# 1/1 - 0s - loss: 0.3871 - accuracy: 0.9524
# Epoch 102/500
# 1/1 - 0s - loss: 0.3852 - accuracy: 0.9524
# Epoch 103/500
# 1/1 - 0s - loss: 0.3831 - accuracy: 0.9524
# Epoch 104/500
# 1/1 - 0s - loss: 0.3809 - accuracy: 0.9524
# Epoch 105/500
# 1/1 - 0s - loss: 0.3786 - accuracy: 0.9524
# Epoch 106/500
# 1/1 - 0s - loss: 0.3763 - accuracy: 0.9524
# Epoch 107/500
# 1/1 - 0s - loss: 0.3741 - accuracy: 0.9524
# Epoch 108/500
# 1/1 - 0s - loss: 0.3720 - accuracy: 0.9524
# Epoch 109/500
# 1/1 - 0s - loss: 0.3700 - accuracy: 0.9524
# Epoch 110/500
# 1/1 - 0s - loss: 0.3680 - accuracy: 0.9524
# Epoch 111/500
# 1/1 - 0s - loss: 0.3660 - accuracy: 0.9524
# Epoch 112/500
# 1/1 - 0s - loss: 0.3638 - accuracy: 0.9524
# Epoch 113/500
# 1/1 - 0s - loss: 0.3617 - accuracy: 0.9524
# Epoch 114/500
# 1/1 - 0s - loss: 0.3596 - accuracy: 0.9524
# Epoch 115/500
# 1/1 - 0s - loss: 0.3575 - accuracy: 0.9524
# Epoch 116/500
# 1/1 - 0s - loss: 0.3556 - accuracy: 0.9524
# Epoch 117/500
# 1/1 - 0s - loss: 0.3536 - accuracy: 0.9524
# Epoch 118/500
# 1/1 - 0s - loss: 0.3516 - accuracy: 0.9524
# Epoch 119/500
# 1/1 - 0s - loss: 0.3496 - accuracy: 0.9524
# Epoch 120/500
# 1/1 - 0s - loss: 0.3476 - accuracy: 0.9524
# Epoch 121/500
# 1/1 - 0s - loss: 0.3456 - accuracy: 0.9524
# Epoch 122/500
# 1/1 - 0s - loss: 0.3436 - accuracy: 0.9524
# Epoch 123/500
# 1/1 - 0s - loss: 0.3417 - accuracy: 0.9524
# Epoch 124/500
# 1/1 - 0s - loss: 0.3398 - accuracy: 0.9524
# Epoch 125/500
# 1/1 - 0s - loss: 0.3378 - accuracy: 0.9524
# Epoch 126/500
# 1/1 - 0s - loss: 0.3359 - accuracy: 0.9524
# Epoch 127/500
# 1/1 - 0s - loss: 0.3341 - accuracy: 0.9524
# Epoch 128/500
# 1/1 - 0s - loss: 0.3322 - accuracy: 0.9524
# Epoch 129/500
# 1/1 - 0s - loss: 0.3303 - accuracy: 0.9524
# Epoch 130/500
# 1/1 - 0s - loss: 0.3284 - accuracy: 0.9524
# Epoch 131/500
# 1/1 - 0s - loss: 0.3265 - accuracy: 0.9524
# Epoch 132/500
# 1/1 - 0s - loss: 0.3246 - accuracy: 0.9524
# Epoch 133/500
# 1/1 - 0s - loss: 0.3228 - accuracy: 0.9524
# Epoch 134/500
# 1/1 - 0s - loss: 0.3209 - accuracy: 0.9524
# Epoch 135/500
# 1/1 - 0s - loss: 0.3191 - accuracy: 0.9524
# Epoch 136/500
# 1/1 - 0s - loss: 0.3173 - accuracy: 0.9524
# Epoch 137/500
# 1/1 - 0s - loss: 0.3155 - accuracy: 0.9524
# Epoch 138/500
# 1/1 - 0s - loss: 0.3137 - accuracy: 0.9524
# Epoch 139/500
# 1/1 - 0s - loss: 0.3119 - accuracy: 0.9524
# Epoch 140/500
# 1/1 - 0s - loss: 0.3101 - accuracy: 0.9524
# Epoch 141/500
# 1/1 - 0s - loss: 0.3083 - accuracy: 0.9524
# Epoch 142/500
# 1/1 - 0s - loss: 0.3065 - accuracy: 0.9524
# Epoch 143/500
# 1/1 - 0s - loss: 0.3048 - accuracy: 0.9524
# Epoch 144/500
# 1/1 - 0s - loss: 0.3030 - accuracy: 0.9524
# Epoch 145/500
# 1/1 - 0s - loss: 0.3012 - accuracy: 0.9524
# Epoch 146/500
# 1/1 - 0s - loss: 0.2995 - accuracy: 0.9524
# Epoch 147/500
# 1/1 - 0s - loss: 0.2978 - accuracy: 0.9524
# Epoch 148/500
# 1/1 - 0s - loss: 0.2961 - accuracy: 0.9524
# Epoch 149/500
# 1/1 - 0s - loss: 0.2943 - accuracy: 0.9524
# Epoch 150/500
# 1/1 - 0s - loss: 0.2926 - accuracy: 0.9524
# Epoch 151/500
# 1/1 - 0s - loss: 0.2909 - accuracy: 0.9524
# Epoch 152/500
# 1/1 - 0s - loss: 0.2893 - accuracy: 0.9524
# Epoch 153/500
# 1/1 - 0s - loss: 0.2876 - accuracy: 0.9524
# Epoch 154/500
# 1/1 - 0s - loss: 0.2859 - accuracy: 0.9524
# Epoch 155/500
# 1/1 - 0s - loss: 0.2842 - accuracy: 0.9524
# Epoch 156/500
# 1/1 - 0s - loss: 0.2826 - accuracy: 0.9524
# Epoch 157/500
# 1/1 - 0s - loss: 0.2809 - accuracy: 0.9524
# Epoch 158/500
# 1/1 - 0s - loss: 0.2793 - accuracy: 0.9524
# Epoch 159/500
# 1/1 - 0s - loss: 0.2776 - accuracy: 0.9524
# Epoch 160/500
# 1/1 - 0s - loss: 0.2760 - accuracy: 0.9524
# Epoch 161/500
# 1/1 - 0s - loss: 0.2744 - accuracy: 0.9524
# Epoch 162/500
# 1/1 - 0s - loss: 0.2727 - accuracy: 0.9524
# Epoch 163/500
# 1/1 - 0s - loss: 0.2711 - accuracy: 0.9524
# Epoch 164/500
# 1/1 - 0s - loss: 0.2695 - accuracy: 0.9524
# Epoch 165/500
# 1/1 - 0s - loss: 0.2679 - accuracy: 0.9524
# Epoch 166/500
# 1/1 - 0s - loss: 0.2663 - accuracy: 0.9524
# Epoch 167/500
# 1/1 - 0s - loss: 0.2648 - accuracy: 0.9524
# Epoch 168/500
# 1/1 - 0s - loss: 0.2632 - accuracy: 0.9524
# Epoch 169/500
# 1/1 - 0s - loss: 0.2616 - accuracy: 0.9524
# Epoch 170/500
# 1/1 - 0s - loss: 0.2601 - accuracy: 0.9524
# Epoch 171/500
# 1/1 - 0s - loss: 0.2585 - accuracy: 0.9524
# Epoch 172/500
# 1/1 - 0s - loss: 0.2570 - accuracy: 0.9524
# Epoch 173/500
# 1/1 - 0s - loss: 0.2554 - accuracy: 0.9524
# Epoch 174/500
# 1/1 - 0s - loss: 0.2539 - accuracy: 0.9524
# Epoch 175/500
# 1/1 - 0s - loss: 0.2524 - accuracy: 0.9524
# Epoch 176/500
# 1/1 - 0s - loss: 0.2508 - accuracy: 0.9524
# Epoch 177/500
# 1/1 - 0s - loss: 0.2493 - accuracy: 0.9524
# Epoch 178/500
# 1/1 - 0s - loss: 0.2478 - accuracy: 0.9524
# Epoch 179/500
# 1/1 - 0s - loss: 0.2462 - accuracy: 0.9524
# Epoch 180/500
# 1/1 - 0s - loss: 0.2447 - accuracy: 0.9524
# Epoch 181/500
# 1/1 - 0s - loss: 0.2432 - accuracy: 0.9524
# Epoch 182/500
# 1/1 - 0s - loss: 0.2418 - accuracy: 0.9524
# Epoch 183/500
# 1/1 - 0s - loss: 0.2404 - accuracy: 0.9524
# Epoch 184/500
# 1/1 - 0s - loss: 0.2389 - accuracy: 0.9524
# Epoch 185/500
# 1/1 - 0s - loss: 0.2376 - accuracy: 0.9524
# Epoch 186/500
# 1/1 - 0s - loss: 0.2362 - accuracy: 0.9524
# Epoch 187/500
# 1/1 - 0s - loss: 0.2348 - accuracy: 0.9524
# Epoch 188/500
# 1/1 - 0s - loss: 0.2335 - accuracy: 0.9524
# Epoch 189/500
# 1/1 - 0s - loss: 0.2321 - accuracy: 0.9524
# Epoch 190/500
# 1/1 - 0s - loss: 0.2308 - accuracy: 0.9524
# Epoch 191/500
# 1/1 - 0s - loss: 0.2295 - accuracy: 0.9524
# Epoch 192/500
# 1/1 - 0s - loss: 0.2282 - accuracy: 0.9524
# Epoch 193/500
# 1/1 - 0s - loss: 0.2269 - accuracy: 0.9524
# Epoch 194/500
# 1/1 - 0s - loss: 0.2256 - accuracy: 0.9524
# Epoch 195/500
# 1/1 - 0s - loss: 0.2243 - accuracy: 0.9524
# Epoch 196/500
# 1/1 - 0s - loss: 0.2231 - accuracy: 0.9524
# Epoch 197/500
# 1/1 - 0s - loss: 0.2219 - accuracy: 0.9524
# Epoch 198/500
# 1/1 - 0s - loss: 0.2206 - accuracy: 0.9524
# Epoch 199/500
# 1/1 - 0s - loss: 0.2194 - accuracy: 0.9524
# Epoch 200/500
# 1/1 - 0s - loss: 0.2182 - accuracy: 0.9524
# Epoch 201/500
# 1/1 - 0s - loss: 0.2170 - accuracy: 0.9524
# Epoch 202/500
# 1/1 - 0s - loss: 0.2158 - accuracy: 0.9524
# Epoch 203/500
# 1/1 - 0s - loss: 0.2146 - accuracy: 0.9524
# Epoch 204/500
# 1/1 - 0s - loss: 0.2135 - accuracy: 0.9524
# Epoch 205/500
# 1/1 - 0s - loss: 0.2123 - accuracy: 0.9524
# Epoch 206/500
# 1/1 - 0s - loss: 0.2112 - accuracy: 0.9524
# Epoch 207/500
# 1/1 - 0s - loss: 0.2100 - accuracy: 0.9524
# Epoch 208/500
# 1/1 - 0s - loss: 0.2089 - accuracy: 0.9524
# Epoch 209/500
# 1/1 - 0s - loss: 0.2078 - accuracy: 0.9524
# Epoch 210/500
# 1/1 - 0s - loss: 0.2066 - accuracy: 0.9524
# Epoch 211/500
# 1/1 - 0s - loss: 0.2055 - accuracy: 0.9524
# Epoch 212/500
# 1/1 - 0s - loss: 0.2044 - accuracy: 0.9524
# Epoch 213/500
# 1/1 - 0s - loss: 0.2033 - accuracy: 0.9524
# Epoch 214/500
# 1/1 - 0s - loss: 0.2023 - accuracy: 0.9524
# Epoch 215/500
# 1/1 - 0s - loss: 0.2012 - accuracy: 0.9524
# Epoch 216/500
# 1/1 - 0s - loss: 0.2001 - accuracy: 0.9524
# Epoch 217/500
# 1/1 - 0s - loss: 0.1991 - accuracy: 0.9524
# Epoch 218/500
# 1/1 - 0s - loss: 0.1980 - accuracy: 0.9524
# Epoch 219/500
# 1/1 - 0s - loss: 0.1970 - accuracy: 0.9524
# Epoch 220/500
# 1/1 - 0s - loss: 0.1959 - accuracy: 0.9524
# Epoch 221/500
# 1/1 - 0s - loss: 0.1949 - accuracy: 0.9524
# Epoch 222/500
# 1/1 - 0s - loss: 0.1939 - accuracy: 0.9524
# Epoch 223/500
# 1/1 - 0s - loss: 0.1929 - accuracy: 0.9524
# Epoch 224/500
# 1/1 - 0s - loss: 0.1919 - accuracy: 0.9524
# Epoch 225/500
# 1/1 - 0s - loss: 0.1909 - accuracy: 0.9524
# Epoch 226/500
# 1/1 - 0s - loss: 0.1899 - accuracy: 0.9524
# Epoch 227/500
# 1/1 - 0s - loss: 0.1889 - accuracy: 0.9524
# Epoch 228/500
# 1/1 - 0s - loss: 0.1879 - accuracy: 0.9524
# Epoch 229/500
# 1/1 - 0s - loss: 0.1870 - accuracy: 0.9524
# Epoch 230/500
# 1/1 - 0s - loss: 0.1860 - accuracy: 0.9524
# Epoch 231/500
# 1/1 - 0s - loss: 0.1850 - accuracy: 0.9524
# Epoch 232/500
# 1/1 - 0s - loss: 0.1841 - accuracy: 0.9524
# Epoch 233/500
# 1/1 - 0s - loss: 0.1832 - accuracy: 0.9524
# Epoch 234/500
# 1/1 - 0s - loss: 0.1822 - accuracy: 0.9524
# Epoch 235/500
# 1/1 - 0s - loss: 0.1813 - accuracy: 0.9524
# Epoch 236/500
# 1/1 - 0s - loss: 0.1804 - accuracy: 0.9524
# Epoch 237/500
# 1/1 - 0s - loss: 0.1795 - accuracy: 0.9524
# Epoch 238/500
# 1/1 - 0s - loss: 0.1786 - accuracy: 0.9524
# Epoch 239/500
# 1/1 - 0s - loss: 0.1777 - accuracy: 0.9524
# Epoch 240/500
# 1/1 - 0s - loss: 0.1768 - accuracy: 0.9524
# Epoch 241/500
# 1/1 - 0s - loss: 0.1759 - accuracy: 0.9524
# Epoch 242/500
# 1/1 - 0s - loss: 0.1751 - accuracy: 0.9524
# Epoch 243/500
# 1/1 - 0s - loss: 0.1742 - accuracy: 0.9524
# Epoch 244/500
# 1/1 - 0s - loss: 0.1733 - accuracy: 0.9524
# Epoch 245/500
# 1/1 - 0s - loss: 0.1725 - accuracy: 0.9524
# Epoch 246/500
# 1/1 - 0s - loss: 0.1717 - accuracy: 0.9524
# Epoch 247/500
# 1/1 - 0s - loss: 0.1708 - accuracy: 0.9524
# Epoch 248/500
# 1/1 - 0s - loss: 0.1700 - accuracy: 0.9524
# Epoch 249/500
# 1/1 - 0s - loss: 0.1692 - accuracy: 0.9524
# Epoch 250/500
# 1/1 - 0s - loss: 0.1683 - accuracy: 0.9524
# Epoch 251/500
# 1/1 - 0s - loss: 0.1675 - accuracy: 0.9524
# Epoch 252/500
# 1/1 - 0s - loss: 0.1667 - accuracy: 0.9524
# Epoch 253/500
# 1/1 - 0s - loss: 0.1659 - accuracy: 0.9524
# Epoch 254/500
# 1/1 - 0s - loss: 0.1651 - accuracy: 0.9524
# Epoch 255/500
# 1/1 - 0s - loss: 0.1643 - accuracy: 0.9524
# Epoch 256/500
# 1/1 - 0s - loss: 0.1636 - accuracy: 0.9524
# Epoch 257/500
# 1/1 - 0s - loss: 0.1628 - accuracy: 0.9524
# Epoch 258/500
# 1/1 - 0s - loss: 0.1620 - accuracy: 0.9524
# Epoch 259/500
# 1/1 - 0s - loss: 0.1613 - accuracy: 0.9524
# Epoch 260/500
# 1/1 - 0s - loss: 0.1605 - accuracy: 0.9524
# Epoch 261/500
# 1/1 - 0s - loss: 0.1598 - accuracy: 0.9524
# Epoch 262/500
# 1/1 - 0s - loss: 0.1590 - accuracy: 0.9524
# Epoch 263/500
# 1/1 - 0s - loss: 0.1583 - accuracy: 0.9524
# Epoch 264/500
# 1/1 - 0s - loss: 0.1576 - accuracy: 0.9524
# Epoch 265/500
# 1/1 - 0s - loss: 0.1568 - accuracy: 0.9524
# Epoch 266/500
# 1/1 - 0s - loss: 0.1561 - accuracy: 0.9524
# Epoch 267/500
# 1/1 - 0s - loss: 0.1554 - accuracy: 0.9524
# Epoch 268/500
# 1/1 - 0s - loss: 0.1547 - accuracy: 0.9524
# Epoch 269/500
# 1/1 - 0s - loss: 0.1540 - accuracy: 0.9524
# Epoch 270/500
# 1/1 - 0s - loss: 0.1533 - accuracy: 0.9524
# Epoch 271/500
# 1/1 - 0s - loss: 0.1526 - accuracy: 0.9524
# Epoch 272/500
# 1/1 - 0s - loss: 0.1520 - accuracy: 0.9524
# Epoch 273/500
# 1/1 - 0s - loss: 0.1513 - accuracy: 0.9524
# Epoch 274/500
# 1/1 - 0s - loss: 0.1506 - accuracy: 0.9524
# Epoch 275/500
# 1/1 - 0s - loss: 0.1500 - accuracy: 0.9524
# Epoch 276/500
# 1/1 - 0s - loss: 0.1493 - accuracy: 0.9524
# Epoch 277/500
# 1/1 - 0s - loss: 0.1487 - accuracy: 0.9524
# Epoch 278/500
# 1/1 - 0s - loss: 0.1480 - accuracy: 0.9524
# Epoch 279/500
# 1/1 - 0s - loss: 0.1474 - accuracy: 0.9524
# Epoch 280/500
# 1/1 - 0s - loss: 0.1468 - accuracy: 0.9524
# Epoch 281/500
# 1/1 - 0s - loss: 0.1462 - accuracy: 0.9524
# Epoch 282/500
# 1/1 - 0s - loss: 0.1456 - accuracy: 0.9524
# Epoch 283/500
# 1/1 - 0s - loss: 0.1449 - accuracy: 0.9524
# Epoch 284/500
# 1/1 - 0s - loss: 0.1443 - accuracy: 0.9524
# Epoch 285/500
# 1/1 - 0s - loss: 0.1438 - accuracy: 0.9524
# Epoch 286/500
# 1/1 - 0s - loss: 0.1432 - accuracy: 0.9524
# Epoch 287/500
# 1/1 - 0s - loss: 0.1426 - accuracy: 0.9524
# Epoch 288/500
# 1/1 - 0s - loss: 0.1420 - accuracy: 0.9524
# Epoch 289/500
# 1/1 - 0s - loss: 0.1415 - accuracy: 0.9524
# Epoch 290/500
# 1/1 - 0s - loss: 0.1409 - accuracy: 0.9524
# Epoch 291/500
# 1/1 - 0s - loss: 0.1403 - accuracy: 0.9524
# Epoch 292/500
# 1/1 - 0s - loss: 0.1398 - accuracy: 0.9524
# Epoch 293/500
# 1/1 - 0s - loss: 0.1392 - accuracy: 0.9524
# Epoch 294/500
# 1/1 - 0s - loss: 0.1387 - accuracy: 0.9524
# Epoch 295/500
# 1/1 - 0s - loss: 0.1382 - accuracy: 0.9524
# Epoch 296/500
# 1/1 - 0s - loss: 0.1377 - accuracy: 0.9524
# Epoch 297/500
# 1/1 - 0s - loss: 0.1371 - accuracy: 0.9524
# Epoch 298/500
# 1/1 - 0s - loss: 0.1366 - accuracy: 0.9524
# Epoch 299/500
# 1/1 - 0s - loss: 0.1361 - accuracy: 0.9524
# Epoch 300/500
# 1/1 - 0s - loss: 0.1356 - accuracy: 0.9524
# Epoch 301/500
# 1/1 - 0s - loss: 0.1351 - accuracy: 0.9524
# Epoch 302/500
# 1/1 - 0s - loss: 0.1346 - accuracy: 0.9524
# Epoch 303/500
# 1/1 - 0s - loss: 0.1341 - accuracy: 0.9524
# Epoch 304/500
# 1/1 - 0s - loss: 0.1336 - accuracy: 0.9524
# Epoch 305/500
# 1/1 - 0s - loss: 0.1331 - accuracy: 0.9524
# Epoch 306/500
# 1/1 - 0s - loss: 0.1327 - accuracy: 0.9524
# Epoch 307/500
# 1/1 - 0s - loss: 0.1322 - accuracy: 0.9524
# Epoch 308/500
# 1/1 - 0s - loss: 0.1317 - accuracy: 0.9524
# Epoch 309/500
# 1/1 - 0s - loss: 0.1313 - accuracy: 0.9524
# Epoch 310/500
# 1/1 - 0s - loss: 0.1308 - accuracy: 0.9524
# Epoch 311/500
# 1/1 - 0s - loss: 0.1304 - accuracy: 0.9524
# Epoch 312/500
# 1/1 - 0s - loss: 0.1299 - accuracy: 0.9524
# Epoch 313/500
# 1/1 - 0s - loss: 0.1295 - accuracy: 0.9524
# Epoch 314/500
# 1/1 - 0s - loss: 0.1290 - accuracy: 0.9524
# Epoch 315/500
# 1/1 - 0s - loss: 0.1286 - accuracy: 0.9524
# Epoch 316/500
# 1/1 - 0s - loss: 0.1281 - accuracy: 0.9524
# Epoch 317/500
# 1/1 - 0s - loss: 0.1277 - accuracy: 0.9524
# Epoch 318/500
# 1/1 - 0s - loss: 0.1273 - accuracy: 0.9524
# Epoch 319/500
# 1/1 - 0s - loss: 0.1269 - accuracy: 0.9524
# Epoch 320/500
# 1/1 - 0s - loss: 0.1265 - accuracy: 0.9524
# Epoch 321/500
# 1/1 - 0s - loss: 0.1260 - accuracy: 0.9524
# Epoch 322/500
# 1/1 - 0s - loss: 0.1256 - accuracy: 0.9524
# Epoch 323/500
# 1/1 - 0s - loss: 0.1252 - accuracy: 0.9524
# Epoch 324/500
# 1/1 - 0s - loss: 0.1248 - accuracy: 0.9524
# Epoch 325/500
# 1/1 - 0s - loss: 0.1244 - accuracy: 0.9524
# Epoch 326/500
# 1/1 - 0s - loss: 0.1240 - accuracy: 0.9524
# Epoch 327/500
# 1/1 - 0s - loss: 0.1236 - accuracy: 0.9524
# Epoch 328/500
# 1/1 - 0s - loss: 0.1232 - accuracy: 0.9524
# Epoch 329/500
# 1/1 - 0s - loss: 0.1229 - accuracy: 0.9524
# Epoch 330/500
# 1/1 - 0s - loss: 0.1225 - accuracy: 0.9524
# Epoch 331/500
# 1/1 - 0s - loss: 0.1221 - accuracy: 0.9524
# Epoch 332/500
# 1/1 - 0s - loss: 0.1217 - accuracy: 0.9524
# Epoch 333/500
# 1/1 - 0s - loss: 0.1214 - accuracy: 0.9524
# Epoch 334/500
# 1/1 - 0s - loss: 0.1210 - accuracy: 0.9524
# Epoch 335/500
# 1/1 - 0s - loss: 0.1206 - accuracy: 0.9524
# Epoch 336/500
# 1/1 - 0s - loss: 0.1203 - accuracy: 0.9524
# Epoch 337/500
# 1/1 - 0s - loss: 0.1199 - accuracy: 0.9524
# Epoch 338/500
# 1/1 - 0s - loss: 0.1195 - accuracy: 0.9524
# Epoch 339/500
# 1/1 - 0s - loss: 0.1192 - accuracy: 0.9524
# Epoch 340/500
# 1/1 - 0s - loss: 0.1188 - accuracy: 0.9524
# Epoch 341/500
# 1/1 - 0s - loss: 0.1185 - accuracy: 0.9524
# Epoch 342/500
# 1/1 - 0s - loss: 0.1182 - accuracy: 0.9524
# Epoch 343/500
# 1/1 - 0s - loss: 0.1178 - accuracy: 0.9524
# Epoch 344/500
# 1/1 - 0s - loss: 0.1175 - accuracy: 0.9524
# Epoch 345/500
# 1/1 - 0s - loss: 0.1171 - accuracy: 0.9524
# Epoch 346/500
# 1/1 - 0s - loss: 0.1168 - accuracy: 0.9524
# Epoch 347/500
# 1/1 - 0s - loss: 0.1165 - accuracy: 0.9524
# Epoch 348/500
# 1/1 - 0s - loss: 0.1162 - accuracy: 0.9524
# Epoch 349/500
# 1/1 - 0s - loss: 0.1158 - accuracy: 0.9524
# Epoch 350/500
# 1/1 - 0s - loss: 0.1155 - accuracy: 0.9524
# Epoch 351/500
# 1/1 - 0s - loss: 0.1152 - accuracy: 0.9524
# Epoch 352/500
# 1/1 - 0s - loss: 0.1149 - accuracy: 0.9524
# Epoch 353/500
# 1/1 - 0s - loss: 0.1146 - accuracy: 0.9524
# Epoch 354/500
# 1/1 - 0s - loss: 0.1143 - accuracy: 0.9524
# Epoch 355/500
# 1/1 - 0s - loss: 0.1140 - accuracy: 0.9524
# Epoch 356/500
# 1/1 - 0s - loss: 0.1136 - accuracy: 0.9524
# Epoch 357/500
# 1/1 - 0s - loss: 0.1133 - accuracy: 0.9524
# Epoch 358/500
# 1/1 - 0s - loss: 0.1130 - accuracy: 0.9524
# Epoch 359/500
# 1/1 - 0s - loss: 0.1128 - accuracy: 0.9524
# Epoch 360/500
# 1/1 - 0s - loss: 0.1125 - accuracy: 0.9524
# Epoch 361/500
# 1/1 - 0s - loss: 0.1122 - accuracy: 0.9524
# Epoch 362/500
# 1/1 - 0s - loss: 0.1119 - accuracy: 0.9524
# Epoch 363/500
# 1/1 - 0s - loss: 0.1116 - accuracy: 0.9524
# Epoch 364/500
# 1/1 - 0s - loss: 0.1113 - accuracy: 0.9524
# Epoch 365/500
# 1/1 - 0s - loss: 0.1110 - accuracy: 0.9524
# Epoch 366/500
# 1/1 - 0s - loss: 0.1107 - accuracy: 0.9524
# Epoch 367/500
# 1/1 - 0s - loss: 0.1105 - accuracy: 0.9524
# Epoch 368/500
# 1/1 - 0s - loss: 0.1102 - accuracy: 0.9524
# Epoch 369/500
# 1/1 - 0s - loss: 0.1099 - accuracy: 0.9524
# Epoch 370/500
# 1/1 - 0s - loss: 0.1097 - accuracy: 0.9524
# Epoch 371/500
# 1/1 - 0s - loss: 0.1094 - accuracy: 0.9524
# Epoch 372/500
# 1/1 - 0s - loss: 0.1091 - accuracy: 0.9524
# Epoch 373/500
# 1/1 - 0s - loss: 0.1089 - accuracy: 0.9524
# Epoch 374/500
# 1/1 - 0s - loss: 0.1086 - accuracy: 0.9524
# Epoch 375/500
# 1/1 - 0s - loss: 0.1083 - accuracy: 0.9524
# Epoch 376/500
# 1/1 - 0s - loss: 0.1081 - accuracy: 0.9524
# Epoch 377/500
# 1/1 - 0s - loss: 0.1078 - accuracy: 0.9524
# Epoch 378/500
# 1/1 - 0s - loss: 0.1076 - accuracy: 0.9524
# Epoch 379/500
# 1/1 - 0s - loss: 0.1073 - accuracy: 0.9524
# Epoch 380/500
# 1/1 - 0s - loss: 0.1071 - accuracy: 0.9524
# Epoch 381/500
# 1/1 - 0s - loss: 0.1068 - accuracy: 0.9524
# Epoch 382/500
# 1/1 - 0s - loss: 0.1066 - accuracy: 0.9524
# Epoch 383/500
# 1/1 - 0s - loss: 0.1063 - accuracy: 0.9524
# Epoch 384/500
# 1/1 - 0s - loss: 0.1061 - accuracy: 0.9524
# Epoch 385/500
# 1/1 - 0s - loss: 0.1059 - accuracy: 0.9524
# Epoch 386/500
# 1/1 - 0s - loss: 0.1056 - accuracy: 0.9524
# Epoch 387/500
# 1/1 - 0s - loss: 0.1054 - accuracy: 0.9524
# Epoch 388/500
# 1/1 - 0s - loss: 0.1052 - accuracy: 0.9524
# Epoch 389/500
# 1/1 - 0s - loss: 0.1049 - accuracy: 0.9524
# Epoch 390/500
# 1/1 - 0s - loss: 0.1047 - accuracy: 0.9524
# Epoch 391/500
# 1/1 - 0s - loss: 0.1045 - accuracy: 0.9524
# Epoch 392/500
# 1/1 - 0s - loss: 0.1043 - accuracy: 0.9524
# Epoch 393/500
# 1/1 - 0s - loss: 0.1040 - accuracy: 0.9524
# Epoch 394/500
# 1/1 - 0s - loss: 0.1038 - accuracy: 0.9524
# Epoch 395/500
# 1/1 - 0s - loss: 0.1036 - accuracy: 0.9524
# Epoch 396/500
# 1/1 - 0s - loss: 0.1034 - accuracy: 0.9524
# Epoch 397/500
# 1/1 - 0s - loss: 0.1032 - accuracy: 0.9524
# Epoch 398/500
# 1/1 - 0s - loss: 0.1030 - accuracy: 0.9524
# Epoch 399/500
# 1/1 - 0s - loss: 0.1027 - accuracy: 0.9524
# Epoch 400/500
# 1/1 - 0s - loss: 0.1025 - accuracy: 0.9524
# Epoch 401/500
# 1/1 - 0s - loss: 0.1023 - accuracy: 0.9524
# Epoch 402/500
# 1/1 - 0s - loss: 0.1021 - accuracy: 0.9524
# Epoch 403/500
# 1/1 - 0s - loss: 0.1019 - accuracy: 0.9524
# Epoch 404/500
# 1/1 - 0s - loss: 0.1017 - accuracy: 0.9524
# Epoch 405/500
# 1/1 - 0s - loss: 0.1015 - accuracy: 0.9524
# Epoch 406/500
# 1/1 - 0s - loss: 0.1013 - accuracy: 0.9524
# Epoch 407/500
# 1/1 - 0s - loss: 0.1011 - accuracy: 0.9524
# Epoch 408/500
# 1/1 - 0s - loss: 0.1009 - accuracy: 0.9524
# Epoch 409/500
# 1/1 - 0s - loss: 0.1007 - accuracy: 0.9524
# Epoch 410/500
# 1/1 - 0s - loss: 0.1005 - accuracy: 0.9524
# Epoch 411/500
# 1/1 - 0s - loss: 0.1003 - accuracy: 0.9524
# Epoch 412/500
# 1/1 - 0s - loss: 0.1001 - accuracy: 0.9524
# Epoch 413/500
# 1/1 - 0s - loss: 0.0999 - accuracy: 0.9524
# Epoch 414/500
# 1/1 - 0s - loss: 0.0998 - accuracy: 0.9524
# Epoch 415/500
# 1/1 - 0s - loss: 0.0996 - accuracy: 0.9524
# Epoch 416/500
# 1/1 - 0s - loss: 0.0994 - accuracy: 0.9524
# Epoch 417/500
# 1/1 - 0s - loss: 0.0992 - accuracy: 0.9524
# Epoch 418/500
# 1/1 - 0s - loss: 0.0990 - accuracy: 0.9524
# Epoch 419/500
# 1/1 - 0s - loss: 0.0988 - accuracy: 0.9524
# Epoch 420/500
# 1/1 - 0s - loss: 0.0987 - accuracy: 0.9524
# Epoch 421/500
# 1/1 - 0s - loss: 0.0985 - accuracy: 0.9524
# Epoch 422/500
# 1/1 - 0s - loss: 0.0983 - accuracy: 0.9524
# Epoch 423/500
# 1/1 - 0s - loss: 0.0981 - accuracy: 0.9524
# Epoch 424/500
# 1/1 - 0s - loss: 0.0980 - accuracy: 0.9524
# Epoch 425/500
# 1/1 - 0s - loss: 0.0978 - accuracy: 0.9524
# Epoch 426/500
# 1/1 - 0s - loss: 0.0976 - accuracy: 0.9524
# Epoch 427/500
# 1/1 - 0s - loss: 0.0974 - accuracy: 0.9524
# Epoch 428/500
# 1/1 - 0s - loss: 0.0973 - accuracy: 0.9524
# Epoch 429/500
# 1/1 - 0s - loss: 0.0971 - accuracy: 0.9524
# Epoch 430/500
# 1/1 - 0s - loss: 0.0969 - accuracy: 0.9524
# Epoch 431/500
# 1/1 - 0s - loss: 0.0968 - accuracy: 0.9524
# Epoch 432/500
# 1/1 - 0s - loss: 0.0966 - accuracy: 0.9524
# Epoch 433/500
# 1/1 - 0s - loss: 0.0965 - accuracy: 0.9524
# Epoch 434/500
# 1/1 - 0s - loss: 0.0963 - accuracy: 0.9524
# Epoch 435/500
# 1/1 - 0s - loss: 0.0961 - accuracy: 0.9524
# Epoch 436/500
# 1/1 - 0s - loss: 0.0960 - accuracy: 0.9524
# Epoch 437/500
# 1/1 - 0s - loss: 0.0958 - accuracy: 0.9524
# Epoch 438/500
# 1/1 - 0s - loss: 0.0957 - accuracy: 0.9524
# Epoch 439/500
# 1/1 - 0s - loss: 0.0955 - accuracy: 0.9524
# Epoch 440/500
# 1/1 - 0s - loss: 0.0954 - accuracy: 0.9524
# Epoch 441/500
# 1/1 - 0s - loss: 0.0952 - accuracy: 0.9524
# Epoch 442/500
# 1/1 - 0s - loss: 0.0950 - accuracy: 0.9524
# Epoch 443/500
# 1/1 - 0s - loss: 0.0949 - accuracy: 0.9524
# Epoch 444/500
# 1/1 - 0s - loss: 0.0947 - accuracy: 0.9524
# Epoch 445/500
# 1/1 - 0s - loss: 0.0946 - accuracy: 0.9524
# Epoch 446/500
# 1/1 - 0s - loss: 0.0945 - accuracy: 0.9524
# Epoch 447/500
# 1/1 - 0s - loss: 0.0943 - accuracy: 0.9524
# Epoch 448/500
# 1/1 - 0s - loss: 0.0942 - accuracy: 0.9524
# Epoch 449/500
# 1/1 - 0s - loss: 0.0940 - accuracy: 0.9524
# Epoch 450/500
# 1/1 - 0s - loss: 0.0939 - accuracy: 0.9524
# Epoch 451/500
# 1/1 - 0s - loss: 0.0937 - accuracy: 0.9524
# Epoch 452/500
# 1/1 - 0s - loss: 0.0936 - accuracy: 0.9524
# Epoch 453/500
# 1/1 - 0s - loss: 0.0935 - accuracy: 0.9524
# Epoch 454/500
# 1/1 - 0s - loss: 0.0933 - accuracy: 0.9524
# Epoch 455/500
# 1/1 - 0s - loss: 0.0932 - accuracy: 0.9524
# Epoch 456/500
# 1/1 - 0s - loss: 0.0930 - accuracy: 0.9524
# Epoch 457/500
# 1/1 - 0s - loss: 0.0929 - accuracy: 0.9524
# Epoch 458/500
# 1/1 - 0s - loss: 0.0928 - accuracy: 0.9524
# Epoch 459/500
# 1/1 - 0s - loss: 0.0926 - accuracy: 0.9524
# Epoch 460/500
# 1/1 - 0s - loss: 0.0925 - accuracy: 0.9524
# Epoch 461/500
# 1/1 - 0s - loss: 0.0924 - accuracy: 0.9524
# Epoch 462/500
# 1/1 - 0s - loss: 0.0922 - accuracy: 0.9524
# Epoch 463/500
# 1/1 - 0s - loss: 0.0921 - accuracy: 0.9524
# Epoch 464/500
# 1/1 - 0s - loss: 0.0920 - accuracy: 0.9524
# Epoch 465/500
# 1/1 - 0s - loss: 0.0918 - accuracy: 0.9524
# Epoch 466/500
# 1/1 - 0s - loss: 0.0917 - accuracy: 0.9524
# Epoch 467/500
# 1/1 - 0s - loss: 0.0916 - accuracy: 0.9524
# Epoch 468/500
# 1/1 - 0s - loss: 0.0915 - accuracy: 0.9524
# Epoch 469/500
# 1/1 - 0s - loss: 0.0913 - accuracy: 0.9524
# Epoch 470/500
# 1/1 - 0s - loss: 0.0912 - accuracy: 0.9524
# Epoch 471/500
# 1/1 - 0s - loss: 0.0911 - accuracy: 0.9524
# Epoch 472/500
# 1/1 - 0s - loss: 0.0910 - accuracy: 0.9524
# Epoch 473/500
# 1/1 - 0s - loss: 0.0908 - accuracy: 0.9524
# Epoch 474/500
# 1/1 - 0s - loss: 0.0907 - accuracy: 0.9524
# Epoch 475/500
# 1/1 - 0s - loss: 0.0906 - accuracy: 0.9524
# Epoch 476/500
# 1/1 - 0s - loss: 0.0905 - accuracy: 0.9524
# Epoch 477/500
# 1/1 - 0s - loss: 0.0904 - accuracy: 0.9524
# Epoch 478/500
# 1/1 - 0s - loss: 0.0902 - accuracy: 0.9524
# Epoch 479/500
# 1/1 - 0s - loss: 0.0901 - accuracy: 0.9524
# Epoch 480/500
# 1/1 - 0s - loss: 0.0900 - accuracy: 0.9524
# Epoch 481/500
# 1/1 - 0s - loss: 0.0899 - accuracy: 0.9524
# Epoch 482/500
# 1/1 - 0s - loss: 0.0898 - accuracy: 0.9524
# Epoch 483/500
# 1/1 - 0s - loss: 0.0897 - accuracy: 0.9524
# Epoch 484/500
# 1/1 - 0s - loss: 0.0896 - accuracy: 0.9524
# Epoch 485/500
# 1/1 - 0s - loss: 0.0894 - accuracy: 0.9524
# Epoch 486/500
# 1/1 - 0s - loss: 0.0893 - accuracy: 0.9524
# Epoch 487/500
# 1/1 - 0s - loss: 0.0892 - accuracy: 0.9524
# Epoch 488/500
# 1/1 - 0s - loss: 0.0891 - accuracy: 0.9524
# Epoch 489/500
# 1/1 - 0s - loss: 0.0890 - accuracy: 0.9524
# Epoch 490/500
# 1/1 - 0s - loss: 0.0889 - accuracy: 0.9524
# Epoch 491/500
# 1/1 - 0s - loss: 0.0888 - accuracy: 0.9524
# Epoch 492/500
# 1/1 - 0s - loss: 0.0887 - accuracy: 0.9524
# Epoch 493/500
# 1/1 - 0s - loss: 0.0886 - accuracy: 0.9524
# Epoch 494/500
# 1/1 - 0s - loss: 0.0885 - accuracy: 0.9524
# Epoch 495/500
# 1/1 - 0s - loss: 0.0884 - accuracy: 0.9524
# Epoch 496/500
# 1/1 - 0s - loss: 0.0883 - accuracy: 0.9524
# Epoch 497/500
# 1/1 - 0s - loss: 0.0882 - accuracy: 0.9524
# Epoch 498/500
# 1/1 - 0s - loss: 0.0881 - accuracy: 0.9524
# Epoch 499/500
# 1/1 - 0s - loss: 0.0879 - accuracy: 0.9524
# Epoch 500/500
# 1/1 - 0s - loss: 0.0878 - accuracy: 0.9524

# %%
# generate a sequence from a language model
def generate_seq_line_by_line(model, tokenizer, max_length, seed_text, n_words):
  in_text = seed_text
  # generate a fixed number of words
  for _ in range(n_words):
    # encode the text as integer
    encoded = tokenizer.texts_to_sequences([in_text])[0]
    # pre-pad sequences to a fixed length
    encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
    # predict probabilities for each word
    yhat = model.predict_classes(encoded, verbose=0)
    # map predicted word index to word
    out_word = ''
    for word, index in tokenizer.word_index.items():
      if index == yhat:
        out_word = word
        break
    # append to input
    in_text += ' ' + out_word
  return in_text

# %%
print(generate_seq_line_by_line(model_line_by_line, tokenizer, max_length, "Jack", 20))
# Out:
# Jack fell down down and broke his crown crown hill hill hill hill hill hill water water water water water water
