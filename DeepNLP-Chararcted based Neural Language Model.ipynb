# %%
# load doc into memory
def load_doc(filename):
  # open the file as read only
  file = open(filename, 'r')
  # read all text
  text = file.read()
  # close the file
  file.close()
  return text

# %%
# load text
raw_text = load_doc('/content/rhyme.txt')
print(raw_text)
# Out:
# Sing a song of sixpence,
# A pocket full of rye.
# Four and twenty blackbirds,
# Baked in a pie.
#
# When the pie was opened
# The birds began to sing;
# Wasn't that a dainty dish,
# To set before the king.
#
# The king was in his counting house,
# Counting out his money;
# The queen was in the parlour,
# Eating bread and honey.
#
# The maid was in the garden,
# Hanging out the clothes,
# When down came a blackbird
# And pecked off her nose.

# %%
# clean
tokens = raw_text.split()
raw_text = ' '.join(tokens)

# %%
# organize into sequences of characters
length = 10
sequences = list()
for i in range(length, len(raw_text)):
# select sequence of tokens
  seq = raw_text[i-length:i+1]
  # store
  sequences.append(seq)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 399

# %%
sequences[0:5]
# Out:
# ['Sing a song', 'ing a song ', 'ng a song o', 'g a song of', ' a song of ']

# %%
# save tokens to file, one dialog per line
def save_doc(lines, filename):
  data = '\n'.join(lines)
  file = open(filename, 'w')
  file.write(data)
  file.close()
# save sequences to file
out_filename = '/content/char_sequences.txt'
save_doc(sequences, out_filename)

# %%
#loading the character sequence data
# load
in_filename = '/content/char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')

# %%
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))

# %%
sequences = list()
for line in lines:
# integer encode line
  encoded_seq = [mapping[char] for char in line]
  # store
  sequences.append(encoded_seq)

# %%
# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 38

# %%
import numpy as np
sequences = np.array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]

# %%
from keras.utils import to_categorical
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = np.array(sequences)
y = to_categorical(y, num_classes=vocab_size)

# %%
from keras import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from keras.layers import LSTM
# define the model
def define_model(X):
  model = Sequential()
  model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
  model.add(Dense(vocab_size, activation='softmax'))
  # compile model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  # summarize defined model
  model.summary()
  plot_model(model, to_file='model.png', show_shapes=True)
  return model

# %%
model = define_model(X)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 75)                34200
# _________________________________________________________________
# dense (Dense)                (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# save the model to file
model.save('model.h5')

# %%
# save the mapping
from pickle import dump
dump(mapping, open('/content/mapping.pkl', 'wb'))

# %%
from numpy import array
from pickle import dump
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# load doc into memory
def load_doc(filename):
  # open the file as read only
  file = open(filename, 'r')
  # read all text
  text = file.read()
  # close the file
  file.close()
  return text
# define the model
def define_model(X):
  model = Sequential()
  model.add(LSTM(75, input_shape=(X.shape[1], X.shape[2])))
  model.add(Dense(vocab_size, activation='softmax'))
  # compile model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
  # summarize defined model
  model.summary()
  plot_model(model, to_file='model.png', show_shapes=True)
  return model
# load
in_filename = '/content/char_sequences.txt'
raw_text = load_doc(in_filename)
lines = raw_text.split('\n')
# integer encode sequences of characters
chars = sorted(list(set(raw_text)))
mapping = dict((c, i) for i, c in enumerate(chars))
sequences = list()
for line in lines:
  # integer encode line
  encoded_seq = [mapping[char] for char in line]
  # store
  sequences.append(encoded_seq)
# vocabulary size
vocab_size = len(mapping)
print('Vocabulary Size: %d' % vocab_size)
# separate into input and output
sequences = array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
sequences = [to_categorical(x, num_classes=vocab_size) for x in X]
X = array(sequences)
y = to_categorical(y, num_classes=vocab_size)
# define model
model = define_model(X)
# fit model
model.fit(X, y, epochs=100, verbose=2)
# save the model to file
model.save('model.h5')
# save the mapping
dump(mapping, open('mapping.pkl', 'wb'))
# Out:
# Vocabulary Size: 38
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 75)                34200
# _________________________________________________________________
# dense_1 (Dense)              (None, 38)                2888
# =================================================================
# Total params: 37,088
# Trainable params: 37,088
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 - 0s - loss: 3.6094 - accuracy: 0.0852
# Epoch 2/100
# 13/13 - 0s - loss: 3.4905 - accuracy: 0.1830
# Epoch 3/100
# 13/13 - 0s - loss: 3.1847 - accuracy: 0.1905
# Epoch 4/100
# 13/13 - 0s - loss: 3.0554 - accuracy: 0.1905
# Epoch 5/100
# 13/13 - 0s - loss: 3.0044 - accuracy: 0.1905
# Epoch 6/100
# 13/13 - 0s - loss: 2.9842 - accuracy: 0.1905
# Epoch 7/100
# 13/13 - 0s - loss: 2.9687 - accuracy: 0.1905
# Epoch 8/100
# 13/13 - 0s - loss: 2.9542 - accuracy: 0.1905
# Epoch 9/100
# 13/13 - 0s - loss: 2.9407 - accuracy: 0.1905
# Epoch 10/100
# 13/13 - 0s - loss: 2.9171 - accuracy: 0.1905
# Epoch 11/100
# 13/13 - 0s - loss: 2.8991 - accuracy: 0.1905
# Epoch 12/100
# 13/13 - 0s - loss: 2.8827 - accuracy: 0.1905
# Epoch 13/100
# 13/13 - 0s - loss: 2.8627 - accuracy: 0.1905
# Epoch 14/100
# 13/13 - 0s - loss: 2.8411 - accuracy: 0.2607
# Epoch 15/100
# 13/13 - 0s - loss: 2.7967 - accuracy: 0.2155
# Epoch 16/100
# 13/13 - 0s - loss: 2.7619 - accuracy: 0.2281
# Epoch 17/100
# 13/13 - 0s - loss: 2.7309 - accuracy: 0.2431
# Epoch 18/100
# 13/13 - 0s - loss: 2.6883 - accuracy: 0.2431
# Epoch 19/100
# 13/13 - 0s - loss: 2.6376 - accuracy: 0.2506
# Epoch 20/100
# 13/13 - 0s - loss: 2.6091 - accuracy: 0.3008
# Epoch 21/100
# 13/13 - 0s - loss: 2.5501 - accuracy: 0.3233
# Epoch 22/100
# 13/13 - 0s - loss: 2.5225 - accuracy: 0.2882
# Epoch 23/100
# 13/13 - 0s - loss: 2.4586 - accuracy: 0.3308
# Epoch 24/100
# 13/13 - 0s - loss: 2.4120 - accuracy: 0.3308
# Epoch 25/100
# 13/13 - 0s - loss: 2.3768 - accuracy: 0.3434
# Epoch 26/100
# 13/13 - 0s - loss: 2.3399 - accuracy: 0.3584
# Epoch 27/100
# 13/13 - 0s - loss: 2.2704 - accuracy: 0.3559
# Epoch 28/100
# 13/13 - 0s - loss: 2.2131 - accuracy: 0.3684
# Epoch 29/100
# 13/13 - 0s - loss: 2.1786 - accuracy: 0.3709
# Epoch 30/100
# 13/13 - 0s - loss: 2.1198 - accuracy: 0.4261
# Epoch 31/100
# 13/13 - 0s - loss: 2.0829 - accuracy: 0.4336
# Epoch 32/100
# 13/13 - 0s - loss: 2.0309 - accuracy: 0.4436
# Epoch 33/100
# 13/13 - 0s - loss: 2.0435 - accuracy: 0.4160
# Epoch 34/100
# 13/13 - 0s - loss: 1.9916 - accuracy: 0.4311
# Epoch 35/100
# 13/13 - 0s - loss: 1.9497 - accuracy: 0.4436
# Epoch 36/100
# 13/13 - 0s - loss: 1.9445 - accuracy: 0.4586
# Epoch 37/100
# 13/13 - 0s - loss: 1.8537 - accuracy: 0.4862
# Epoch 38/100
# 13/13 - 0s - loss: 1.8210 - accuracy: 0.4762
# Epoch 39/100
# 13/13 - 0s - loss: 1.7905 - accuracy: 0.4862
# Epoch 40/100
# 13/13 - 0s - loss: 1.7407 - accuracy: 0.4987
# Epoch 41/100
# 13/13 - 0s - loss: 1.6944 - accuracy: 0.5088
# Epoch 42/100
# 13/13 - 0s - loss: 1.6498 - accuracy: 0.5113
# Epoch 43/100
# 13/13 - 0s - loss: 1.6145 - accuracy: 0.5238
# Epoch 44/100
# 13/13 - 0s - loss: 1.5867 - accuracy: 0.5439
# Epoch 45/100
# 13/13 - 0s - loss: 1.5567 - accuracy: 0.5439
# Epoch 46/100
# 13/13 - 0s - loss: 1.5379 - accuracy: 0.5689
# Epoch 47/100
# 13/13 - 0s - loss: 1.4814 - accuracy: 0.5865
# Epoch 48/100
# 13/13 - 0s - loss: 1.4672 - accuracy: 0.6065
# Epoch 49/100
# 13/13 - 0s - loss: 1.4160 - accuracy: 0.6040
# Epoch 50/100
# 13/13 - 0s - loss: 1.4071 - accuracy: 0.6115
# Epoch 51/100
# 13/13 - 0s - loss: 1.3899 - accuracy: 0.6391
# Epoch 52/100
# 13/13 - 0s - loss: 1.3296 - accuracy: 0.6416
# Epoch 53/100
# 13/13 - 0s - loss: 1.2963 - accuracy: 0.6591
# Epoch 54/100
# 13/13 - 0s - loss: 1.2484 - accuracy: 0.6817
# Epoch 55/100
# 13/13 - 0s - loss: 1.2201 - accuracy: 0.6767
# Epoch 56/100
# 13/13 - 0s - loss: 1.1756 - accuracy: 0.7043
# Epoch 57/100
# 13/13 - 0s - loss: 1.1525 - accuracy: 0.7243
# Epoch 58/100
# 13/13 - 0s - loss: 1.1549 - accuracy: 0.7168
# Epoch 59/100
# 13/13 - 0s - loss: 1.0790 - accuracy: 0.7594
# Epoch 60/100
# 13/13 - 0s - loss: 1.0698 - accuracy: 0.7469
# Epoch 61/100
# 13/13 - 0s - loss: 1.0319 - accuracy: 0.7820
# Epoch 62/100
# 13/13 - 0s - loss: 0.9862 - accuracy: 0.7945
# Epoch 63/100
# 13/13 - 0s - loss: 0.9603 - accuracy: 0.7995
# Epoch 64/100
# 13/13 - 0s - loss: 0.9477 - accuracy: 0.8045
# Epoch 65/100
# 13/13 - 0s - loss: 0.9074 - accuracy: 0.8346
# Epoch 66/100
# 13/13 - 0s - loss: 0.8682 - accuracy: 0.8396
# Epoch 67/100
# 13/13 - 0s - loss: 0.8449 - accuracy: 0.8371
# Epoch 68/100
# 13/13 - 0s - loss: 0.8079 - accuracy: 0.8672
# Epoch 69/100
# 13/13 - 0s - loss: 0.7901 - accuracy: 0.8622
# Epoch 70/100
# 13/13 - 0s - loss: 0.7616 - accuracy: 0.8747
# Epoch 71/100
# 13/13 - 0s - loss: 0.7346 - accuracy: 0.8972
# Epoch 72/100
# 13/13 - 0s - loss: 0.7128 - accuracy: 0.8997
# Epoch 73/100
# 13/13 - 0s - loss: 0.6880 - accuracy: 0.8997
# Epoch 74/100
# 13/13 - 0s - loss: 0.6760 - accuracy: 0.8997
# Epoch 75/100
# 13/13 - 0s - loss: 0.6390 - accuracy: 0.9298
# Epoch 76/100
# 13/13 - 0s - loss: 0.6191 - accuracy: 0.9373
# Epoch 77/100
# 13/13 - 0s - loss: 0.6072 - accuracy: 0.9323
# Epoch 78/100
# 13/13 - 0s - loss: 0.5843 - accuracy: 0.9323
# Epoch 79/100
# 13/13 - 0s - loss: 0.5662 - accuracy: 0.9449
# Epoch 80/100
# 13/13 - 0s - loss: 0.5331 - accuracy: 0.9524
# Epoch 81/100
# 13/13 - 0s - loss: 0.5341 - accuracy: 0.9624
# Epoch 82/100
# 13/13 - 0s - loss: 0.5154 - accuracy: 0.9524
# Epoch 83/100
# 13/13 - 0s - loss: 0.4930 - accuracy: 0.9574
# Epoch 84/100
# 13/13 - 0s - loss: 0.4741 - accuracy: 0.9524
# Epoch 85/100
# 13/13 - 0s - loss: 0.4631 - accuracy: 0.9649
# Epoch 86/100
# 13/13 - 0s - loss: 0.4402 - accuracy: 0.9674
# Epoch 87/100
# 13/13 - 0s - loss: 0.4189 - accuracy: 0.9674
# Epoch 88/100
# 13/13 - 0s - loss: 0.3925 - accuracy: 0.9749
# Epoch 89/100
# 13/13 - 0s - loss: 0.3799 - accuracy: 0.9749
# Epoch 90/100
# 13/13 - 0s - loss: 0.3660 - accuracy: 0.9799
# Epoch 91/100
# 13/13 - 0s - loss: 0.3560 - accuracy: 0.9774
# Epoch 92/100
# 13/13 - 0s - loss: 0.3595 - accuracy: 0.9774
# Epoch 93/100
# 13/13 - 0s - loss: 0.3361 - accuracy: 0.9900
# Epoch 94/100
# 13/13 - 0s - loss: 0.3215 - accuracy: 0.9850
# Epoch 95/100
# 13/13 - 0s - loss: 0.3191 - accuracy: 0.9825
# Epoch 96/100
# 13/13 - 0s - loss: 0.3041 - accuracy: 0.9850
# Epoch 97/100
# 13/13 - 0s - loss: 0.2841 - accuracy: 0.9925
# Epoch 98/100
# 13/13 - 0s - loss: 0.2783 - accuracy: 0.9925
# Epoch 99/100
# 13/13 - 0s - loss: 0.2693 - accuracy: 0.9850
# Epoch 100/100
# 13/13 - 0s - loss: 0.2628 - accuracy: 0.9850

# %% [markdown]
# # Generating new text from a sequence of text

# %%
from pickle import load
from keras.models import load_model
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
# generate a sequence of characters with a language model
def generate_seq(model, mapping, seq_length, seed_text, n_chars):
  in_text = seed_text
  # generate a fixed number of characters
  for _ in range(n_chars):
    # encode the characters as integers
    encoded = [mapping[char] for char in in_text]
    # truncate sequences to a fixed length
    encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
    # one hot encode
    encoded = to_categorical(encoded, num_classes=len(mapping))
    encoded = encoded.reshape(1, encoded.shape[1], encoded.shape[2])
    # predict character
    yhat = model.predict_classes(encoded, verbose=0)
    # reverse map integer to character
    out_char = ''
    for char, index in mapping.items():
      if index == yhat:
        out_char = char
        break
    # append to input
    in_text += out_char
  return in_text
# load the model
model = load_model('/content/model.h5')
# load the mapping
mapping = load(open('/content/mapping.pkl', 'rb'))
# test start of rhyme
print(generate_seq(model, mapping, 10, 'Sing a son', 20))
# test mid-line
print(generate_seq(model, mapping, 10, 'king was i', 20))
# test not in original
print(generate_seq(model, mapping, 10, 'hello worl', 20))
# Out:
# Sing a song of sixpence, A poc
# king was in his counting house
# hello worl hee  aine. heentie

# %%
#text to generate from
in_text = 'Sing a son'
# load the model
model = load_model('/content/model.h5')
# load the mapping
mapping = load(open('/content/mapping.pkl', 'rb'))
# encode the characters as integers
encoded = [mapping[char] for char in in_text]

# %%
encoded
# Out:
# [12, 23, 27, 21, 1, 15, 1, 32, 28, 27]

# %%
# one hot encode
encoded = to_categorical(encoded, num_classes=len(mapping))

# %%
encoded = encoded.reshape(1, encoded.shape[0], encoded.shape[1])

# %%
encoded.shape
# Out:
# (1, 10, 38)

# %%
# predict character
# yhat = model.predict_classes(encoded, verbose=0)
yhat = np.argmax(model.predict(encoded), axis=-1)

# %%
out_char = ''
for char, index in mapping.items():
  if index == yhat:
    out_char = char
    break

# %%
out_char
# Out:
# 'g'
